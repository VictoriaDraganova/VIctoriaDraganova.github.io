# %%
import pandas as pd
import plotly.express as px
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# %%
all_teams_df = pd.read_csv('dash_simple_nba_srcdata_shot_dist_compiled_data_2019_20.csv')

# %%
all_teams_df.head()
# Out:
#    Unnamed: 0           player  pl_acc  pl_pps  min_start  min_mid  min_end  \
# 0           0    Jahlil Okafor    65.1   132.6          1      0.5        1
# 1           1     Jaxson Hayes    77.8   155.6          1      0.5        1
# 2           2     Nicolo Melli    36.4    88.6          1      0.5        1
# 3           3  Zion Williamson    54.3   111.4          1      0.5        1
# 4           4    Frank Jackson    44.7   105.3          1      0.5        1
#
#    shots_count  shots_made  shots_freq  shots_acc group
# 0            3           1         3.7       33.3   NOP
# 1            3           2         3.7       66.7   NOP
# 2            1           1         1.2      100.0   NOP
# 3            2           1         2.5       50.0   NOP
# 4            0           0         0.0        0.0   NOP

# %%
app = dash.Dash(__name__)
server = app.server
team_names = all_teams_df.group.unique()
team_names.sort()
app.layout = html.Div([
    html.Div([dcc.Dropdown(id='group-select', options=[{'label': i, 'value': i} for i in team_names],
                           value='TOR', style={'width': '140px'})]),
    dcc.Graph('shot-dist-graph', config={'displayModeBar': False})])

@app.callback(
    Output('shot-dist-graph', 'figure'),
    [Input('group-select', 'value')]
)
def update_graph(grpname):
    import plotly.express as px
    return px.scatter(all_teams_df[all_teams_df.group == grpname], x='min_mid', y='player', size='shots_freq', color='pl_pps')

if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_9_0m1616063263.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-component-suites/dash_renderer/react@16.v1_9_0m1616063263.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_15_0m1616063264.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_9_0m1616063263.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_9_0m1616063263.8.7.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_15_0m1616063264.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_1_2m1616063265.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_9_0m1616063263.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_favicon.ico?v=1.19.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:58] "GET /_dash-component-suites/dash_core_components/async-graph.v1_15_0m1611086576.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:59] "GET /_dash-component-suites/dash_core_components/async-dropdown.v1_15_0m1611086576.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:31:59] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_15_0m1611086576.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:32:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:32:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:32:18] "GET /_dash-component-suites/dash_core_components/async-graph.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:32:18] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:32:18] "GET /_dash-component-suites/dash_core_components/async-dropdown.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:32:18] "GET /_dash-component-suites/dash_html_components/dash_html_components.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:32:18] "GET /_dash-component-suites/dash_core_components/dash_core_components.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:33:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:33:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:34:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:34:56] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:34:56] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:34:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:34:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:35:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:35:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:35:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:35:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Mar/2021 10:35:08] "POST /_dash-update-component HTTP/1.1" 200 -
